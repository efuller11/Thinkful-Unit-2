# %% [markdown]
# Categorize each of the variables in the ESS dataset as categorical or continuous, and if continuous as ordinal, interval, or ratio variables. Check your work with your mentor, and discuss what that information might imply for feature engineering with this data.

# %%
import pandas as pd

# %%
df = pd.read_csv("ESSdata_Thinkful.csv")

# %%
df.head(15)
# Out:
#    cntry  idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  sclact  \
# 0     CH   5.0     6    3.0      3.0     10.0     5.0    8.0      5.0     4.0
# 1     CH  25.0     6    6.0      5.0      7.0     5.0    9.0      3.0     2.0
# 2     CH  26.0     6    1.0      8.0      8.0     8.0    7.0      6.0     3.0
# 3     CH  28.0     6    4.0      6.0      6.0     7.0   10.0      6.0     2.0
# 4     CH  29.0     6    5.0      6.0      7.0     5.0    8.0      7.0     2.0
# 5     CH  36.0     6    4.0      6.0      7.0     3.0    8.0      7.0     4.0
# 6     CH  40.0     6    3.0      0.0      5.0     2.0    0.0      2.0     2.0
# 7     CH  41.0     6    2.0      4.0      5.0     3.0   10.0      5.0     2.0
# 8     CH  51.0     6    2.0      8.0      8.0     8.0    9.0      6.0     4.0
# 9     CH  53.0     6    4.0      4.0      4.0     8.0    7.0      4.0     2.0
# 10    CH  55.0     6    1.0      6.0      7.0     7.0    9.0      5.0     2.0
# ...

# %%
df.describe()
# Out:
#                idno         year        tvtot      ppltrst      pplfair  \
# count  8.594000e+03  8594.000000  8586.000000  8580.000000  8555.000000
# mean   3.954938e+04     6.500000     3.861985     5.559907     6.005143
# std    6.267259e+05     0.500029     2.019689     2.233700     2.129866
# min    1.000000e+00     6.000000     0.000000     0.000000     0.000000
# 25%    1.052000e+03     6.000000     2.000000     4.000000     5.000000
# 50%    1.714000e+03     6.500000     4.000000     6.000000     6.000000
# 75%    2.745000e+03     7.000000     5.000000     7.000000     8.000000
# max    1.100143e+07     7.000000     7.000000    10.000000    10.000000
#
#             pplhlp        happy      sclmeet       sclact         gndr  \
# count  8569.000000  8563.000000  8579.000000  8500.000000  8584.000000
# mean      5.319874     7.694616     5.192563     2.748941     1.497204
# std       2.173449     1.735904     1.457643     0.905477     0.500021
# ...

# %% [markdown]
# cntry -categorical
# idno - categorical
# year - categorical
# tvtot - ratio
# ppltrst - interval, I don't think you can't be too careful is an absolute zero. If they said I trust no one, I would think ratio.
# pplfair - interval, Most people try to take advantage of me is not an absolute zero in my opinion.
# pplhlp - interval, people mostly look out for themselves does not seem to be an absolute zero.
# happy - interval, I cannot even imagine what the absolute zero of being happy would be like.
# sclmeet - ratio, never
# sclact - interval, much less than most is not an absolute zero.
# gndr - categorical
# agea - ratio, is a great example of a ratio it goes from not being born yet to death.
# partner - categorical
